# %%
# Step 1: Mount Google Drive in Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Step # 2: Navigate to the folder
import os
os.chdir('/content/drive/MyDrive/CS471_AI/FinalProject')  # Note: chdir not child

# Verify we are in the right directory
# !pwd
# !ls -la
# Out:
# /content/drive/MyDrive/CS471_AI/FinalProject
# total 53658
# -rw------- 1 root root   217488 May 13 03:52 balacedTrainingModel.ipynb
# -rw------- 1 root root     9659 Apr 28 20:54 checkingDuplicateImages.ipynb
# -rw------- 1 root root   407652 Apr 29 20:51 dataset_visualization.png
# -rw------- 1 root root     4697 May 13 04:49 github_upload.ipynb
# -rw------- 1 root root   810470 Apr 30 00:27 GradientBoostingClassifierAlgo.ipynb
# -rw------- 1 root root   180375 Apr 29 20:51 ImagesCountingBalancedGraph.ipynb
# -rw------- 1 root root 22084712 Apr 30 04:35 jpv0wo8j5_optimized_tflite_mm5zjg2km.tflite
# drwx------ 6 root root     4096 Apr 29 04:33 MangoDataset_Balanced
# drwx------ 6 root root     4096 Apr 30 04:01 MangoRealTestImages
# -rw------- 1 root root    54870 May 13 04:08 optimizeModelAIHub.ipynb
# -rw------- 1 root root   790099 Apr 29 22:50 RandomForestAlgorithm.ipynb
# -rw------- 1 root root 30100764 Apr 30 04:53 TestingWithRealData.ipynb
# ...

# %%
# Step 3: Create a zip file of the project
# Create a zip file of the entire FinalProject folder
# !cd .. && zip -r FinalProject.zip FinalProject/
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: FinalProject/MangoDataset_Balanced/train/VeryRipe/VeryRipe_IMG_2661_copy_25.jpg (deflated 0%)
#   adding: FinalProject/MangoDataset_Balanced/train/VeryRipe/VeryRipe_IMG_2662_copy_24.jpg (deflated 0%)
#   adding: FinalProject/MangoDataset_Balanced/train/VeryRipe/VeryRipe_IMG_2662_copy_3 (1).jpg (deflated 0%)
#   adding: FinalProject/MangoDataset_Balanced/train/VeryRipe/VeryRipe_IMG_2662_copy_17.jpg (deflated 0%)
#   adding: FinalProject/MangoDataset_Balanced/train/VeryRipe/VeryRipe_IMG_2662_copy_7 (1).jpg (deflated 0%)
#   adding: FinalProject/MangoDataset_Balanced/train/VeryRipe/VeryRipe_IMG_2662_copy_22.jpg (deflated 0%)
#   adding: FinalProject/MangoDataset_Balanced/train/VeryRipe/VeryRipe_IMG_2662_copy_19.jpg (deflated 0%)
#   adding: FinalProject/MangoDataset_Balanced/train/VeryRipe/VeryRipe_IMG_2662_copy_21.jpg (deflated 0%)
# ...

# %%
# Step 4: Set up Git and GitHub
# Install Git LFS (Large File Storage) fro handling large files like datasets:
# !sudo apt-get install git-lfs
# !git lfs install
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# git-lfs is already the newest version (3.0.2-1ubuntu0.3).
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.
# Git LFS initialized.

# %%
# Step 5: Clone or create GitHub repo
# !git clone https://github.com/RamosER77/cs--final-project.git
# Out:
# Cloning into 'cs--final-project'...
# ...

# %%
# Step 6: Copy the files to the cloned repo
# Check current directoru
# !pwd
# See what is in current directory
# !ls -la
# Out:
# /content/drive/MyDrive/CS471_AI/FinalProject
# total 54181
# -rw------- 1 root root   217488 May 13 03:52 balacedTrainingModel.ipynb
# -rw------- 1 root root     9659 Apr 28 20:54 checkingDuplicateImages.ipynb
# drwx------ 3 root root     4096 May 13 05:41 cs--final-project
# -rw------- 1 root root   407652 Apr 29 20:51 dataset_visualization.png
# -rw------- 1 root root   536454 May 13 05:44 github_upload.ipynb
# -rw------- 1 root root   810470 Apr 30 00:27 GradientBoostingClassifierAlgo.ipynb
# -rw------- 1 root root   180375 Apr 29 20:51 ImagesCountingBalancedGraph.ipynb
# -rw------- 1 root root 22084712 Apr 30 04:35 jpv0wo8j5_optimized_tflite_mm5zjg2km.tflite
# drwx------ 6 root root     4096 Apr 29 04:33 MangoDataset_Balanced
# drwx------ 6 root root     4096 Apr 30 04:01 MangoRealTestImages
# -rw------- 1 root root    54870 May 13 04:08 optimizeModelAIHub.ipynb
# -rw------- 1 root root   790099 Apr 29 22:50 RandomForestAlgorithm.ipynb
# ...

# %%
# First, let's check if the repository was cloned
# !ls -la /content/

# If the directory exists but is empty, let's copy files differently
# Since we're already in the FinalProject directory, let's copy everything
# !cp -r . /content/cs--final-project/

# OR if the directory doesn't exist at all, let's create it first
# !mkdir -p /content/cs--final-project
# !cp -r ./* /content/cs--final-project/
# !cp -r ./.* /content/cs--final-project/ 2>/dev/null || true  # Copy hidden files too

# Now change to the repository directory
# %cd /content/cs--final-project
# !ls -la
# Out:
# total 20
# drwxr-xr-x 1 root root 4096 May 13 04:48 .
# drwxr-xr-x 1 root root 4096 May 13 04:47 ..
# drwxr-xr-x 4 root root 4096 May  9 13:41 .config
# drwx------ 7 root root 4096 May 13 04:48 drive
# drwxr-xr-x 1 root root 4096 May  9 13:41 sample_data

# %%
# Step 6: Configure Git
# !git config --global user.email "erubielramos9@gmail.com"
# !git config --global user.name "Erubiel Ramos"

# %%
# Step 7: Copy files to repo
# If you cloned an exiting repo
# !cp -r /content/drive/MyDrive/CS471_AI/FinalProject/* /content/cs471-final-project/
# Out:
# cp: target '/content/cs471-final-project/' is not a directory

# %%
# Step 8: Set up Git LFS for large files
# Track large files like datasets and models:
# !cd /content/https://github.com/RamosER77/cs--final-project.git
# !git lfs track "*.png"
# !git lfs track "*.jpg"
# !git lfs track "*.tflite"
# !git lfs track "* MangoDataset_Balanced"
# !git lfs track "* MangoRealTestImages"

# %%
# Step 9: Add and commit files
# !cd /content/https://github.com/RamosER77/cs--final-project.git
# !git add .
# !git commit -m "Add CS471 Final Project - Mango classification with dataset and algorithms"

# %%
# Step 10: Push to GitHub
# !git push origin main
